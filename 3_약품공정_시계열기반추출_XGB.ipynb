# %% [markdown]
# # 스마트 정수장 알고리즘 시계열기반 추출 학습: 약품 공정

# %% [markdown]
# ### 1. 필요한 Python 라이브러리 Import 하기

# %%
import numpy as np
import pandas as pd
import datetime
import scipy
import random
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import r_regression
from sklearn.linear_model import LinearRegression, Lasso, Ridge

# RandomForestRegressor를 임포트합니다.
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import pickle
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import platform

if platform.system() == "Darwin":  #
    plt.rc("font", family="AppleGothic")
else:
    plt.rc("font", family="NanumGothic")

fe = fm.FontEntry(
    fname=r"/usr/share/fonts/truetype/nanum/NanumGothic.ttf",  # ttf 파일이 저장되어 있는 경로
    name="NanumGothic",
)  # 원하는 폰트 설정
fm.fontManager.ttflist.insert(0, fe)  # Matplotlib에 폰트 추가

plt.rcParams.update({"font.size": 18, "font.family": "NanumGothic"})  # 폰트 설정

plt.rcParams["axes.unicode_minus"] = False

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'  # Windows 기본 한글 폰트
plt.rcParams['axes.unicode_minus'] = False     # 마이너스 부호 깨짐 방지

# %% [markdown]
# ### 2. 전처리된 데이터 불러오기

# %%
load_df = pd.read_csv("SN_total.csv")
load_df = load_df.set_index("시간")
load_df.index = pd.DatetimeIndex(load_df.index)
raw_df = load_df.copy()
raw_df.head(5)
# Out:
#                         원수 탁도     원수 pH    원수 알칼리도    원수 전기전도도     원수 수온  \
# 시간
# 2020-01-01 12:59:00  2.477549  8.257175  54.961955  222.781944  4.616253
# 2020-01-01 13:29:00  2.439258  8.271153  55.155387  222.880161  4.629616
# 2020-01-01 13:59:00  2.421914  8.282444  55.320712  224.263970  4.629758
# 2020-01-01 14:29:00  2.398210  8.286200  55.872316  224.579963  4.626820
# 2020-01-01 14:59:00  2.408023  8.288734  56.368194  224.477999  4.620842
#
#                      3단계 원수 유입 유량  3단계 1계열 응집제 주입률  3단계 침전지 탁도  3단계 침전지 체류시간  \
# 시간
# 2020-01-01 12:59:00  11183.916667         13.54400    0.282890    256.817051
# 2020-01-01 13:29:00  11205.916667         13.55400    0.291072    260.570714
# 2020-01-01 13:59:00  11503.791667         13.59700    0.297960    270.520977
# 2020-01-01 14:29:00  11781.125000         13.66800    0.312246    260.697341
# 2020-01-01 14:59:00  12237.833333         13.68725    0.317849    238.363311
#
#                      3단계 여과지 탁도
# 시간
# ...

# %% [markdown]
# ### 3. 변수 추가 (Log)

# %%
df = raw_df.copy()

# %%
df["로그 원수 탁도"] = np.log10(df["원수 탁도"])
df["로그 응집제 주입률"] = np.log10(df["3단계 1계열 응집제 주입률"])
df
# Out:
#                         원수 탁도     원수 pH    원수 알칼리도    원수 전기전도도     원수 수온  \
# 시간
# 2020-01-01 12:59:00  2.477549  8.257175  54.961955  222.781944  4.616253
# 2020-01-01 13:29:00  2.439258  8.271153  55.155387  222.880161  4.629616
# 2020-01-01 13:59:00  2.421914  8.282444  55.320712  224.263970  4.629758
# 2020-01-01 14:29:00  2.398210  8.286200  55.872316  224.579963  4.626820
# 2020-01-01 14:59:00  2.408023  8.288734  56.368194  224.477999  4.620842
# ...                       ...       ...        ...         ...       ...
# 2022-12-31 20:59:00  1.787780  7.822680  41.094511  184.020745  3.158893
# 2022-12-31 21:29:00  1.784237  7.820758  40.703410  183.270915  3.163575
# 2022-12-31 21:59:00  1.765750  7.818412  40.405968  182.062842  3.166926
# 2022-12-31 22:29:00  1.785479  7.814997  40.534102  182.261220  3.177002
# 2022-12-31 22:59:00  1.783193  7.815051  40.200702  183.509316  3.177524
#
#                      3단계 원수 유입 유량  3단계 1계열 응집제 주입률  3단계 침전지 탁도  3단계 침전지 체류시간  \
# 시간
# ...

# %%
X = df[
    [
        "로그 원수 탁도",
        "원수 pH",
        "원수 알칼리도",
        "원수 전기전도도",
        "원수 수온",
        "3단계 원수 유입 유량",
        "3단계 침전지 체류시간",
    ]
]
y = df["로그 응집제 주입률"]
Xt, Xts, yt, yts = train_test_split(X, y, test_size=0.2, shuffle=False)

# %% [markdown]
# ### 4. XGBoost 모델 개발

# %%
from xgboost import XGBRegressor

regressor = XGBRegressor(random_state=2, n_jobs=-1)

params = {
    "max_depth": [2],
    "n_estimators": [100],
    "eta": [0.02],
    "subsample": [0.8],
    "min_child_weight": [1],
}

rscv = RandomizedSearchCV(regressor, params, n_iter=30)
rscv.fit(Xt, yt)
model = rscv.best_estimator_
model
# Out:
# c:\ProgramData\miniconda3\envs\pyproject\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 1 is smaller than n_iter=30. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eta=0.02, eval_metric=None,
#              feature_types=None, feature_weights=None, gamma=None,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=2, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
# ...

# %% [markdown]
# ### 5. 모델 성능평가

# %%
yt_pred = model.predict(Xt)
yts_pred = model.predict(Xts)

mse_train = mean_squared_error(10**yt, 10**yt_pred)
mse_test = mean_squared_error(10**yts, 10**yts_pred)
print(f"학습 데이터 MSE: {mse_train}")
print(f"테스트 데이터 MSE: {mse_test}")

r2_train = r2_score(10**yt, 10**yt_pred)
r2_test = r2_score(10**yts, 10**yts_pred)
print(f"학습 데이터 R2: {r2_train}")
print(f"테스트 데이터 R2: {r2_test}")
# Out:
# 학습 데이터 MSE: 7.360769986151296
# 테스트 데이터 MSE: 9.079637927501459
# 학습 데이터 R2: 0.7256769388469142
# 테스트 데이터 R2: 0.7977910029412523

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
ax = axes[0]
ax.scatter(Xt["로그 원수 탁도"], yt, s=3, label="학습 데이터 (실제)")
ax.scatter(Xt["로그 원수 탁도"], yt_pred, s=3, label="학습 데이터 (예측)", c="r")
ax.grid()
ax.legend(fontsize=13)
ax.set_xlabel("로그 원수 탁도")
ax.set_ylabel("로그 응집제 주입률")
ax.set_title(
    rf"학습 데이터  MSE: {round(mse_train, 4)}, $R^2$: {round(r2_train, 2)}",
    fontsize=18,
)

ax = axes[1]
ax.scatter(Xts["로그 원수 탁도"], yts, s=3, label="테스트 데이터 (실제)")
ax.scatter(Xts["로그 원수 탁도"], yts_pred, s=3, label="테스트 데이터 (예측)", c="r")
ax.grid()
ax.legend(fontsize=13)
ax.set_xlabel("로그 원수 탁도")
ax.set_ylabel("로그 응집제 주입률")
ax.set_title(
    rf"테스트 데이터  MSE: {round(mse_test, 4)}, $R^2$: {round(r2_test, 2)}",
    fontsize=18,
)
# Out:
# Text(0.5, 1.0, '테스트 데이터  MSE: 9.0796, $R^2$: 0.8')

# %% [markdown]
# ### 6. XGB 저장 및 불러와서 사용하기

# %%
with open("xgb_ex1.pickle", "wb") as f:
    pickle.dump(rscv, f)

# %%
with open("xgb_ex1.pickle", "rb") as f:
    xgb_model = pickle.load(f)

# %%
from sklearn.metrics import mean_squared_error

# 테스트 세트의 레이블을 예측합니다.
y_pred = xgb_model.predict(Xts)

# rmse를 계산합니다.
mse_test = mean_squared_error(10**yts, 10**y_pred)

# rmse를 출력합니다.
print("테스트 세트 점수: {:.3f}".format(mse_test))
# Out:
# 테스트 세트 점수: 9.080

# %% [markdown]
# ### 7. Explainable AI using SHAP

# %%
import shap

# %%
# XGBRegressor를 임포트합니다.
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error as MSE

# XGBRegressor를 초기화합니다.
xg_reg = XGBRegressor(
    max_depth=3, n_estimators=100, eta=0.02, subsample=0.75, random_state=2
)

# 훈련 세트에서 xg_reg를 훈련합니다.
xg_reg.fit(Xt, yt)

# 테스트 세트에 대한 예측을 만듭니다.
y_pred = xg_reg.predict(Xts)

# 평균 제곱근 오차(RMSE) 계산합니다.
MSE(yts, y_pred)
# Out:
# 0.0030931036051679815

# %%
Xt.iloc[0, :]
# Out:
# 로그 원수 탁도            0.394022
# 원수 pH               8.257175
# 원수 알칼리도            54.961955
# 원수 전기전도도          222.781944
# 원수 수온               4.616253
# 3단계 원수 유입 유량    11183.916667
# 3단계 침전지 체류시간      256.817051
# Name: 2020-01-01 12:59:00, dtype: float64

# %%
y_check = xg_reg.predict(Xt)
y_check
# Out:
# array([1.1648908, 1.1623454, 1.1623454, ..., 1.1550558, 1.1550558,
#        1.1550558], shape=(41256,), dtype=float32)

# %%
# JavaScript 시각화 라이브러리 로드하기
shap.initjs()

# SHAP값으로 모델의 예측을 설명하기
explainer = shap.TreeExplainer(xg_reg)
shap_values = explainer.shap_values(Xt)

# 두
shap.force_plot(
    explainer.expected_value, shap_values[0, :].round(3), Xt.iloc[0, :].round(3), matplotlib=True,
)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
shap.force_plot(
    explainer.expected_value, shap_values[500, :].round(3), Xt.iloc[500, :].round(3), matplotlib=True,
)

# %%
shap.summary_plot(shap_values, Xt)

# %%
shap.summary_plot(shap_values, Xt, plot_type="bar")

# %%
import xgboost

xgboost.plot_importance(xg_reg)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Importance score', ylabel='Features'>

# %%
import math
20000 * math.cos(math.radians(30))
# Out:
# 17320.508075688773
